# %% [markdown]
# 1. YOLO 모델의 이해
#    - Object Detection이 무엇인가? 찾고자하는 클래스를 탐지
#    - YOLO11n 은 어떤 데이터를 학습한 것인가? COCO 데이터셋(Label: 80)
# 2. 내 이미지로 YOLO11n 모델 예측하기
#    - roboflow 에서 데이터 생성
# 3. 유튜브 URL YOLO11n 실시간 예측하기
# 4. 데이터 만드는 방법
#    - 좋은 데이터를 만들기 위해 어떻게 해야 하는가? 해상도가 높은데이터를 레이블 수집 규격에 잘 맞춰서 수집
# 5. 데이터 학습하기
#    - 성능 지표 설명하기
#    - mAP50
#       - IoU 기준을 0.5로 고정했을때, mAP(mean AP -> Precision과 Recall 사이의 관계(PR curve)를 그려서 **면적(Area under curve)**을 구한 게 AP)
#    - mAP50-95
#       - IoU 기준을 0.5에서 0.95까지 0.05 단위로 바꿔가며 (0.5, 0.55, 0.6 … 0.95) mAP를 구해서 평균
#       - 즉 박스가 절반 겹친 경우부터 거의 완벽히 겹쳐야하는 경우까지 전부 고려

# %% [markdown]
# ## 1.모델 불러오기

# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO('yolo11n.pt') # 사전학습된 yolo11n(nano) 모델

model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## 2. 이미지 예측해보기

# %%
# 이미지 1개 예측하기
results = model("./images/yolo_image.jpg", save=True, project="result") # model() == model.predict() # [이미지 여러개] 넣기 가능
results
# Out:
# image 1/1 c:\Users\user\potenup\python7month\YOLOproject\images\yolo_image.jpg: 448x640 7 persons, 3 bicycles, 1 umbrella, 193.4ms
# Speed: 4.2ms preprocess, 193.4ms inference, 5.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to result\predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
print(type(results))
print(len(results)) # 예측한 이미지 수
print(type(results[0]))
# Out:
# <class 'list'>
# 1
# <class 'ultralytics.engine.results.Results'>

# %%
print(len(results[0]))
# Out:
# 11

# %%
results[0] # 이미지 하나에 대한 결과물
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([ 1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  0., 25.,  0.])
# conf: tensor([0.9002, 0.8530, 0.8465, 0.8233, 0.6742, 0.6726, 0.5206, 0.4078, 0.3751, 0.3393, 0.2988])
# data: tensor([[6.2712e+02, 3.9485e+02, 1.0357e+03, 7.7144e+02, 9.0023e-01, 1.0000e+00],
#         [3.8486e+02, 2.1434e+02, 5.8382e+02, 7.4489e+02, 8.5297e-01, 0.0000e+00],
#         [3.1211e+02, 4.2675e+02, 6.2185e+02, 7.6588e+02, 8.4648e-01, 1.0000e+00],
#         [2.0947e+01, 3.8343e+02, 2.8015e+02, 6.5619e+02, 8.2332e-01, 1.0000e+00],
#         [8.3186e+02, 1.8188e+02, 1.0133e+03, 7.0348e+02, 6.7417e-01, 0.0000e+00],
#         [1.1804e+02, 2.4416e+02, 2.8153e+02, 6.3568e+02, 6.7262e-01, 0.0000e+00],
#         [5.9368e+02, 2.1384e+02, 7.9385e+02, 6.7300e+02, 5.2062e-01, 0.0000e+00],
#         [3.4311e+02, 2.6228e+02, 4.2485e+02, 4.9047e+02, 4.0778e-01, 0.0000e+00],
#         [5.9131e+02, 2.1500e+02, 7.9470e+02, 4.3146e+02, 3.7509e-01, 0.0000e+00],
# ...

# %%
results[0].boxes.data
# Out:
# tensor([[6.2712e+02, 3.9485e+02, 1.0357e+03, 7.7144e+02, 9.0023e-01, 1.0000e+00],
#         [3.8486e+02, 2.1434e+02, 5.8382e+02, 7.4489e+02, 8.5297e-01, 0.0000e+00],
#         [3.1211e+02, 4.2675e+02, 6.2185e+02, 7.6588e+02, 8.4648e-01, 1.0000e+00],
#         [2.0947e+01, 3.8343e+02, 2.8015e+02, 6.5619e+02, 8.2332e-01, 1.0000e+00],
#         [8.3186e+02, 1.8188e+02, 1.0133e+03, 7.0348e+02, 6.7417e-01, 0.0000e+00],
#         [1.1804e+02, 2.4416e+02, 2.8153e+02, 6.3568e+02, 6.7262e-01, 0.0000e+00],
#         [5.9368e+02, 2.1384e+02, 7.9385e+02, 6.7300e+02, 5.2062e-01, 0.0000e+00],
#         [3.4311e+02, 2.6228e+02, 4.2485e+02, 4.9047e+02, 4.0778e-01, 0.0000e+00],
#         [5.9131e+02, 2.1500e+02, 7.9470e+02, 4.3146e+02, 3.7509e-01, 0.0000e+00],
#         [3.3718e+02, 2.1136e+02, 5.3825e+02, 3.0413e+02, 3.3927e-01, 2.5000e+01],
#         [1.1850e+02, 2.4364e+02, 2.8135e+02, 5.1767e+02, 2.9876e-01, 0.0000e+00]])

# %%
for rslt in results:
    boxes = rslt.boxes # 이미지에서 디텍션한 객체들에 대한 정보 담겨있음
    masks = rslt.masks
    keypoints = rslt.keypoints
    probs = rslt.probs
    obb = rslt.obb
    names = rslt.names
    rslt.show()
results[0].names
print(names) # yolo11n 모델이 찾을 수 있는 객체 딕셔너리
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %%
for x1, y1, x2, y2 in boxes.xyxy:
    print(x1, y1, x2, y2)
# Out:
# tensor(627.1171) tensor(394.8538) tensor(1035.6875) tensor(771.4446)
# tensor(384.8632) tensor(214.3356) tensor(583.8155) tensor(744.8948)
# tensor(312.1060) tensor(426.7474) tensor(621.8453) tensor(765.8849)
# tensor(20.9471) tensor(383.4302) tensor(280.1525) tensor(656.1851)
# tensor(831.8597) tensor(181.8790) tensor(1013.2870) tensor(703.4780)
# tensor(118.0357) tensor(244.1564) tensor(281.5349) tensor(635.6759)
# tensor(593.6768) tensor(213.8430) tensor(793.8538) tensor(672.9994)
# tensor(343.1068) tensor(262.2825) tensor(424.8450) tensor(490.4669)
# tensor(591.3116) tensor(214.9956) tensor(794.6976) tensor(431.4563)
# tensor(337.1822) tensor(211.3644) tensor(538.2481) tensor(304.1340)
# tensor(118.5022) tensor(243.6358) tensor(281.3510) tensor(517.6674)

# %%
for box in boxes:
    #print(box.xyxy)
    print(box.xyxy[0])
    x1, y1, x2, y2 = box.xyxy[0]
    #(x1, y1, x2, y2)
# Out:
# tensor([ 627.1171,  394.8538, 1035.6875,  771.4446])
# tensor([384.8632, 214.3356, 583.8155, 744.8948])
# tensor([312.1060, 426.7474, 621.8453, 765.8849])
# tensor([ 20.9471, 383.4302, 280.1525, 656.1851])
# tensor([ 831.8597,  181.8790, 1013.2870,  703.4780])
# tensor([118.0357, 244.1564, 281.5349, 635.6759])
# tensor([593.6768, 213.8430, 793.8538, 672.9994])
# tensor([343.1068, 262.2825, 424.8450, 490.4669])
# tensor([591.3116, 214.9956, 794.6976, 431.4563])
# tensor([337.1822, 211.3644, 538.2481, 304.1340])
# tensor([118.5022, 243.6358, 281.3510, 517.6674])

# %%
print(type(boxes))
print(boxes.cls) # 예측 클래스
print(boxes.conf) # 신뢰도(confidence)
print(boxes.data) # x1, y1, x2, y2, conf, cls 가 합쳐져서 한 행에 나온거
print(len(boxes.data))
boxes
# Out:
# <class 'ultralytics.engine.results.Boxes'>
# tensor([ 1.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  0., 25.,  0.])
# tensor([0.9002, 0.8530, 0.8465, 0.8233, 0.6742, 0.6726, 0.5206, 0.4078, 0.3751, 0.3393, 0.2988])
# tensor([[6.2712e+02, 3.9485e+02, 1.0357e+03, 7.7144e+02, 9.0023e-01, 1.0000e+00],
#         [3.8486e+02, 2.1434e+02, 5.8382e+02, 7.4489e+02, 8.5297e-01, 0.0000e+00],
#         [3.1211e+02, 4.2675e+02, 6.2185e+02, 7.6588e+02, 8.4648e-01, 1.0000e+00],
#         [2.0947e+01, 3.8343e+02, 2.8015e+02, 6.5619e+02, 8.2332e-01, 1.0000e+00],
#         [8.3186e+02, 1.8188e+02, 1.0133e+03, 7.0348e+02, 6.7417e-01, 0.0000e+00],
#         [1.1804e+02, 2.4416e+02, 2.8153e+02, 6.3568e+02, 6.7262e-01, 0.0000e+00],
#         [5.9368e+02, 2.1384e+02, 7.9385e+02, 6.7300e+02, 5.2062e-01, 0.0000e+00],
#         [3.4311e+02, 2.6228e+02, 4.2485e+02, 4.9047e+02, 4.0778e-01, 0.0000e+00],
#         [5.9131e+02, 2.1500e+02, 7.9470e+02, 4.3146e+02, 3.7509e-01, 0.0000e+00],
# ...

# %%
pred_names = []
for idx in boxes.cls:
    pred_names.append(names[int(idx)])
print(pred_names)
# Out:
# ['bicycle', 'person', 'bicycle', 'bicycle', 'person', 'person', 'person', 'person', 'person', 'umbrella', 'person']

# %%
# x1, y1, x2, y2, conf, cls 가 합쳐져서 한 행에 나온거
print(boxes.data[0])
# Out:
# tensor([6.2712e+02, 3.9485e+02, 1.0357e+03, 7.7144e+02, 9.0023e-01, 1.0000e+00])

# %%
result = {"x1":[], "y1":[], "x2":[], "y2":[], "conf":[], "cls":[]}
for x1, y1, x2, y2, conf, cls in boxes.data: # x1, y1, x2, y2, conf, cls
    print(x1, y1, x2, y2, conf, cls)
    result["x1"].append(x1)
    result["y1"].append(y1)
    result["x2"].append(x2)
    result["y2"].append(y2)
    result["conf"].append(conf)
    result["cls"].append(cls)
print(result)
# Out:
# tensor(627.1171) tensor(394.8538) tensor(1035.6875) tensor(771.4446) tensor(0.9002) tensor(1.)
# tensor(384.8632) tensor(214.3356) tensor(583.8155) tensor(744.8948) tensor(0.8530) tensor(0.)
# tensor(312.1060) tensor(426.7474) tensor(621.8453) tensor(765.8849) tensor(0.8465) tensor(1.)
# tensor(20.9471) tensor(383.4302) tensor(280.1525) tensor(656.1851) tensor(0.8233) tensor(1.)
# tensor(831.8597) tensor(181.8790) tensor(1013.2870) tensor(703.4780) tensor(0.6742) tensor(0.)
# tensor(118.0357) tensor(244.1564) tensor(281.5349) tensor(635.6759) tensor(0.6726) tensor(0.)
# tensor(593.6768) tensor(213.8430) tensor(793.8538) tensor(672.9994) tensor(0.5206) tensor(0.)
# tensor(343.1068) tensor(262.2825) tensor(424.8450) tensor(490.4669) tensor(0.4078) tensor(0.)
# tensor(591.3116) tensor(214.9956) tensor(794.6976) tensor(431.4563) tensor(0.3751) tensor(0.)
# tensor(337.1822) tensor(211.3644) tensor(538.2481) tensor(304.1340) tensor(0.3393) tensor(25.)
# ...

# %%
# image 하나로 예측하기
# results --- 이미지 개수만큼 리스트로 담겨 있었다 len(results) -> 1
# result = results[0] , results.names --- 딕셔너리로 탐지할 수 있는 객체 저장되어 있음
# boxes = result.boxes --- 객체 인식한 박스 정보들이 들어가 있음
# boxes.cls, boxes.conf, boxes.data
# cls: 객체 예측한 결과
# conf: 신뢰도
# data: 박스좌표(x1, y1, x2, y2), 신뢰도(conf), 결과(cls)

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
import cv2
import matplotlib.pyplot as plt

img_path = "./images/yolo_image.jpg"
image = cv2.imread(img_path)

if image is None:
    print(f"Error: Failed to open ad image file {img_path}")
    exit()

else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.show()

# %%
for x1, y1, x2, y2, conf, clss in boxes.data:
    #박스좌표를 정수 변환
    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
    # 이미지 위에 네모 박스 그리기 (그림 그릴 이미지, (좌상단 좌표), (우하단 촤표), (박스 색), 두께)
    cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 255), 3)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 3. 영상 예측해보기

# %%
youtube_url = "https://youtu.be/S5nsDT5oU90"

# %%
# results = model(youtube_url, stream=True, show=True)
# for res in results:
#     print(res)

# %% [markdown]
# # 4. 내 데이처로 학습하기

# %% [markdown]
# ### 데이터 불러오기

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="o1Yi5kcFlFotAIBlvYpA")
project = rf.workspace("yeonlee-8jzjj").project("myproject-btu4g")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to MyProject-1 in yolov11:: 100%|██████████| 72/72 [00:00<00:00, 647.02it/s]

# %% [markdown]
# ### 모델 불러오기

# %%
from ultralytics import YOLO
model = YOLO('yolo11n.pt')

model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ### 학습하기

# %%
results = model.train(data='MyProject-1/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.191  Python-3.10.18 torch-2.8.0+cpu CPU (Intel Core(TM) Ultra 9 185H)
# ...

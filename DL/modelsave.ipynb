# %% [markdown]
# ## 모델 저장 실습

# %%
import torch.nn as nn
import torch
import torchvision.models as models

# %%
class SampleModel(nn.Module):
    def __init__(self):
        super(SampleModel, self).__init__()
        self.fc = nn.Linear(10, 2)
    
    def forward(self, x):
        x = self.fc(x)


model = SampleModel()

# %% [markdown]
# ## 1. 가중치만 저장하기

# %%
# 학습후 모델을 저장(파라미터(가중치)만 저장해라)

torch.save(model.state_dict(), 'model_weight.pth')

# %%
model.state_dict()
# Out:
# OrderedDict([('fc.weight',
#               tensor([[-0.0051, -0.0817, -0.0812, -0.2908,  0.2104, -0.2902, -0.1732, -0.0108,
#                        -0.2445, -0.0222],
#                       [-0.1111, -0.1825,  0.1540, -0.1024, -0.2520, -0.3103, -0.1864, -0.0769,
#                         0.0854,  0.1871]])),
#              ('fc.bias', tensor([ 0.1735, -0.2642]))])

# %% [markdown]
# ## 2. 모델 전체를 저장

# %%
torch.save(model, 'SimpleModel_full.pth')
